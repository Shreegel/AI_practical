# %%
import numpy as np

# Constants
POPULATION_SIZE = 20
NUM_GENERATIONS = 100
LENGTH_INDIVIDUAL = 4  # Length of the binary representation of the integer
LENGTH_RESIDUAL = 5  # Length of the residual (precision)
MUTATION_RATE = 0.01

# Function to decode binary to integer
def decode(binary):
    return int("".join(str(x) for x in binary), 2)

# Fitness function
def fitness(individual):
    x = decode(individual)
    residual = abs(2 * x**2 - 5 * x + 3)
    return 1 / (residual + 1)  # Adding 1 to avoid division by zero

# Initialize population
def initialize_population():
    return np.random.randint(0, 2, (POPULATION_SIZE, LENGTH_INDIVIDUAL))

# Selection
def selection(population, fitnesses):
    probabilities = fitnesses / fitnesses.sum()
    selected_indices = np.random.choice(np.arange(POPULATION_SIZE), size=POPULATION_SIZE, p=probabilities)
    return population[selected_indices]

# Crossover
def crossover(parent1, parent2):
    point = np.random.randint(1, LENGTH_INDIVIDUAL - 1)
    child1 = np.concatenate((parent1[:point], parent2[point:]))
    child2 = np.concatenate((parent2[:point], parent1[point:]))
    return child1, child2

# Mutation
def mutate(individual):
    for i in range(LENGTH_INDIVIDUAL):
        if np.random.rand() < MUTATION_RATE:
            individual[i] = 1 - individual[i]
    return individual

# Genetic Algorithm
def genetic_algorithm():
    population = initialize_population()

    for generation in range(NUM_GENERATIONS):
        fitnesses = np.array([fitness(ind) for ind in population])
        population = selection(population, fitnesses)

        next_population = []

        for i in range(0, POPULATION_SIZE, 2):
            parent1, parent2 = population[i], population[i + 1]
            child1, child2 = crossover(parent1, parent2)
            next_population.append(mutate(child1))
            next_population.append(mutate(child2))

        population = np.array(next_population)

        best_individual = population[np.argmax(fitnesses)]
        best_fitness = max(fitnesses)

        print(f"Generation {generation + 1}: Best Fitness = {best_fitness}, Best Individual (decoded) = {decode(best_individual)}")

    best_individual = population[np.argmax(fitnesses)]
    return decode(best_individual)

# Run the genetic algorithm
best_solution = genetic_algorithm()
print(f"Best solution found: x = {best_solution}")
# Out:
# Generation 1: Best Fitness = 1.0, Best Individual (decoded) = 2
# Generation 2: Best Fitness = 1.0, Best Individual (decoded) = 2
# Generation 3: Best Fitness = 1.0, Best Individual (decoded) = 2
# Generation 4: Best Fitness = 1.0, Best Individual (decoded) = 0
# Generation 5: Best Fitness = 1.0, Best Individual (decoded) = 5
# Generation 6: Best Fitness = 1.0, Best Individual (decoded) = 5
# Generation 7: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 8: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 9: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 10: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 11: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 12: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 13: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 14: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 15: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 16: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 17: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 18: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 19: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 20: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 21: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 22: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 23: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 24: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 25: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 26: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 27: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 28: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 29: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 30: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 31: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 32: Best Fitness = 1.0, Best Individual (decoded) = 5
# Generation 33: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 34: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 35: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 36: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 37: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 38: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 39: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 40: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 41: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 42: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 43: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 44: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 45: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 46: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 47: Best Fitness = 1.0, Best Individual (decoded) = 9
# Generation 48: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 49: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 50: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 51: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 52: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 53: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 54: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 55: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 56: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 57: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 58: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 59: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 60: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 61: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 62: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 63: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 64: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 65: Best Fitness = 1.0, Best Individual (decoded) = 3
# Generation 66: Best Fitness = 1.0, Best Individual (decoded) = 5
# Generation 67: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 68: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 69: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 70: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 71: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 72: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 73: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 74: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 75: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 76: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 77: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 78: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 79: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 80: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 81: Best Fitness = 1.0, Best Individual (decoded) = 5
# Generation 82: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 83: Best Fitness = 1.0, Best Individual (decoded) = 9
# Generation 84: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 85: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 86: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 87: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 88: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 89: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 90: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 91: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 92: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 93: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 94: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 95: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 96: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 97: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 98: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 99: Best Fitness = 1.0, Best Individual (decoded) = 1
# Generation 100: Best Fitness = 1.0, Best Individual (decoded) = 9
# Best solution found: x = 9
